# %%
#import library yang diperlukan(numpy, pandas, seaborn, matplotlib)
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib

# %%
df= pd.read_csv("tech_fundings.csv")
df
# Out:
#       index         Company                      Website          Region  \
# 0         1        Internxt        https://internxt.com/           Spain
# 1         2        Dockflow         https://dockflow.com         Belgium
# 2         3       api.video            https://api.video          France
# 3         4         Buck.ai             https://buck.ai/   United States
# 4         5       Prodsight     https://www.prodsight.ai  United Kingdom
# ...     ...             ...                          ...             ...
# 3570   3571         Headout      https://www.headout.com   United States
# 3571   3572            OLIO          https://olioex.com/  United Kingdom
# 3572   3573  Trees for Life  https://treesforlife.org.uk  United Kingdom
# 3573   3574     Britishvolt     https://britishvolt.com/  United Kingdom
# 3574   3575         Greenly   https://www.greenly.earth/          France
#
#                      Vertical Funding Amount (USD) Funding Stage Funding Date
# ...

# %%
#periksa type datanya terlebih dahulu
df.dtypes
# Out:
# index                    int64
# Company                 object
# Website                 object
# Region                  object
# Vertical                object
# Funding Amount (USD)    object
# Funding Stage           object
# Funding Date            object
# dtype: object

# %%
#periksa apakah data ada yang kosong
df.isnull().sum()
# Out:
# index                    0
# Company                  0
# Website                  0
# Region                  12
# Vertical                 0
# Funding Amount (USD)     0
# Funding Stage            0
# Funding Date             0
# dtype: int64

# %%
df.tail(10)
# Out:
#       index            Company                         Website  \
# 3565   3566       Volta Trucks        https://voltatrucks.com/
# 3566   3567         WestConnex  https://www.westconnex.com.au/
# 3567   3568  BluSmart Mobility      https://www.blu-smart.com/
# 3568   3569        StreetDrone     https://www.streetdrone.com
# 3569   3570      SmarterTravel  https://www.smartertravel.com/
# 3570   3571            Headout         https://www.headout.com
# 3571   3572               OLIO             https://olioex.com/
# 3572   3573     Trees for Life     https://treesforlife.org.uk
# 3573   3574        Britishvolt        https://britishvolt.com/
# 3574   3575            Greenly      https://www.greenly.earth/
#
#               Region        Vertical Funding Amount (USD)   Funding Stage  \
# 3565          Sweden  Transportation             43334400        Series B
# 3566       Australia  Transportation          16600000000  Private Equity
# ...

# %%
###mengapus kolom data yang tidak digunakan###

# %%
#menghapus kolom index karena tidak digunakan
df.drop(columns=["index"], inplace=True)

# %%
#menghapus kolom website karena tidak digunakan
df.drop(columns=["Website"], inplace=True)

# %%
df.head(10)
# Out:
#        Company          Region                 Vertical Funding Amount (USD)  \
# 0     Internxt           Spain               Blockchain               278940
# 1     Dockflow         Belgium                Logistics               292244
# 2    api.video          France           Developer APIs               300000
# 3      Buck.ai   United States  Artificial Intelligence               300000
# 4    Prodsight  United Kingdom  Artificial Intelligence               529013
# 5     Harvestr          France             B2B Software               650000
# 6      Seatrec   United States        Marine Technology               970000
# 7    BeeCanvas   United States             B2B Software              1000000
# 8  SmartKarrot   United States             B2B Software              1000000
# 9      Prisync          Turkey             B2B Software              1100000
#
#   Funding Stage Funding Date
# 0          Seed       Jan-20
# 1          Seed       Jan-20
# 2          Seed       Jan-20
# ...

# %%
#filter data untuk perusahaan  yang diberikan pendanaan di negara united state

# %%
df2=df.query("Region == 'United States'")
df2.head(10)
# Out:
#           Company         Region                 Vertical  \
# 3         Buck.ai  United States  Artificial Intelligence
# 6         Seatrec  United States        Marine Technology
# 7       BeeCanvas  United States             B2B Software
# 8     SmartKarrot  United States             B2B Software
# 10   Fundraise Up  United States             B2B Software
# 11            Yac  United States             B2B Software
# 12  Cloverleaf.me  United States          Human Resources
# 13         Docket  United States             B2B Software
# 14      Podsights  United States                Marketing
# 15    SIMBA Chain  United States               Blockchain
#
#    Funding Amount (USD) Funding Stage Funding Date
# 3                300000          Seed       Jan-20
# 6                970000          Seed       Jan-20
# 7               1000000          Seed       Jan-20
# 8               1000000         Angel       Jan-20
# 10              1250000          Seed       Jan-20
# ...

# %%
df2.to_csv('Company Fundings US.csv', index=False)
df2 = pd.read_csv('Company Fundings US.csv')
df2
# Out:
#              Company         Region                 Vertical  \
# 0            Buck.ai  United States  Artificial Intelligence
# 1            Seatrec  United States        Marine Technology
# 2          BeeCanvas  United States             B2B Software
# 3        SmartKarrot  United States             B2B Software
# 4       Fundraise Up  United States             B2B Software
# ...              ...            ...                      ...
# 2029  Locus Robotics  United States                 Robotics
# 2030         Discord  United States           Social Network
# 2031           Qwilt  United States       Telecommunications
# 2032   SmarterTravel  United States                   Travel
# 2033         Headout  United States                   Travel
#
#      Funding Amount (USD) Funding Stage Funding Date
# 0                  300000          Seed       Jan-20
# 1                  970000          Seed       Jan-20
# 2                 1000000          Seed       Jan-20
# ...
